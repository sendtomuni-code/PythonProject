# %%
title = 'mr'
name = 'subarna'
f'{title.capitalize()} {name}'
# Out:
# 'Mr subarna'

# %%
f'{title.capitalize()} {name}'
# Out:
# 'Mr subarna'

# %%
full_name = 'subarna sekhar muni'
full_name.title()
# Out:
# 'Subarna Sekhar Muni'

# %%
full_name.capitalize()
# Out:
# 'Subarna sekhar muni'

# %%
full_name_title = f'{title.capitalize()} {full_name.capitalize()}'
full_name_title
# Out:
# 'Mr Subarna sekhar muni'

# %%
full_name_title[0] = 'S'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 full_name_title[0] = 'S'
#
# TypeError: 'str' object does not support item assignment
