# %% [markdown]
# # Arithmetic Assignment Operators

# %%
a = 5
a = a + 3
print(a)
a += 3
print(a)
# Out:
# 8
# 11

# %% [markdown]
# # Concatenation Operators of String

# %%
print("Hello " + "World")
# Out:
# Hello World

# %%
print("Hello " + 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("Hello " + 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Hello " + str(3))
# Out:
# Hello 3

# %%
print("Hello " * 3)
# Out:
# Hello Hello Hello

# %%
print("Hello " * 3 + "World")
# Out:
# Hello Hello Hello World

# %%
print("Hello " * 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("Hello " * 3.5)
#
# TypeError: can't multiply sequence by non-int of type 'float'
