# %%
import random as rd

# %%
lst = [rd.randint(1,10) for i in range(10)]
lst
# Out:
# [10, 2, 1, 3, 1, 10, 4, 6, 9, 7]

# %%
lst = [rd.randint(1,10) for i in 'hello']
lst
# Out:
# [9, 9, 4, 1, 3]

# %%
lst = [i.upper() for i in 'hello']
lst
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
lst = [i.upper() for i in 'hello,&%^']
lst
# Out:
# ['H', 'E', 'L', 'L', 'O', ',', '&', '%', '^']

# %%
lst = [i.upper() for i in 'hello,&%^' if i.isalpha()]
lst
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
lst = [i.upper() for i in 'hello,&%^' if i in 'aeiou']
lst
# Out:
# ['E', 'O']
