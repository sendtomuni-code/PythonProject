# %%
import random as rd

# %%
rd.random()
# Out:
# 0.7811641118139695

# %%
rd.randint(0, 100)
# Out:
# 33

# %%
rd.randrange(1,10,2)
# Out:
# 1

# %%
for i in range(10):
    print(rd.randint(0,100))
# Out:
# 7
# 56
# 13
# 61
# 79
# 31
# 61
# 26
# 41
# 83

# %%
rd.seed(3)

for i in range(10):
    print(rd.randint(0,100))
# Out:
# 30
# 75
# 69
# 16
# 47
# 77
# 60
# 80
# 74
# 8

# %%
rd.seed(5)

for i in range(10):
    print(rd.randint(0,100))
# Out:
# 79
# 32
# 94
# 45
# 88
# 94
# 83
# 67
# 3
# 59

# %%
rd.seed(3)

for i in range(10):
    print(rd.randint(0,100))
# Out:
# 30
# 75
# 69
# 16
# 47
# 77
# 60
# 80
# 74
# 8

# %%
rd.seed(5)

for i in range(10):
    print(rd.randint(0,100))
# Out:
# 79
# 32
# 94
# 45
# 88
# 94
# 83
# 67
# 3
# 59

# %%
random_number = [1,2,3,4,5]
rd.choice(random_number)
# Out:
# 2

# %%
rd.choices(random_number, k=2)
# Out:
# [1, 3]

# %%
rd.shuffle(random_number)

# %%
random_number
# Out:
# [5, 1, 3, 4, 2]

# %%
rd.shuffle(random_number)
random_number
# Out:
# [4, 3, 5, 1, 2]

# %%
lst = [rd.randint(1,10) for i in range(10)]
lst
# Out:
# [7, 5, 3, 7, 3, 2, 3, 10, 10, 8]
