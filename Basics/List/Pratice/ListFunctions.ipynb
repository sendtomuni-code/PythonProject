# %% [markdown]
# ### Adding functions to List

# %%
L1 = [1, 2, 3, 4, 5, 6]

# %%
L1.append(7)

# %%
L1
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
L1.append("hello")
L1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'hello']

# %%
L1.append([8,9])

# %%
L1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'hello', [8, 9]]

# %%
L1.extend([5.6, 6.7,'wprld'])
L1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 'hello', [8, 9], 5.6, 6.7, 'wprld']

# %%
L1.extend(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 L1.extend(5)
#
# TypeError: 'int' object is not iterable

# %%
L1.extend('hello')
L1
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  'hello',
#  [8, 9],
#  5.6,
#  6.7,
#  'wprld',
#  'h',
#  'e',
#  'l',
#  'l',
#  'o',
#  'h',
#  'e',
#  'l',
#  'l',
#  'o']

# %%
L1 = [1, 2, 3, 4, 5, 6]
L1.insert(2,7)
L1
# Out:
# [1, 2, 7, 3, 4, 5, 6]

# %%
L1.insert(2, [7,8])

# %%
L1
# Out:
# [1, 2, [7, 8], 7, 3, 4, 5, 6]

# %% [markdown]
# ### Removing functions from List

# %%
l1 = [1, 2, 3, 4, 5, 6]

# %%
l1.pop()
# Out:
# 6

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1.pop(2)
# Out:
# 3

# %%
l1
# Out:
# [1, 2, 4, 5]

# %%
l2 = []
l2.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 l2 = []
# ----> 2 l2.pop()
#
# IndexError: pop from empty list

# %%
l3 = [1, 2, 3, 4, 5, 3]

# %%
l3.remove(3)

# %%
l3
# Out:
# [1, 2, 4, 5, 3]

# %%
l3.remove(3)
l3
# Out:
# [1, 2, 4, 5]

# %%
del l3[2]

# %%
l3
# Out:
# [1, 2, 5]

# %%
l3.extend([1,2,3,4,5])

# %%
l3
# Out:
# [1, 2, 5, 1, 2, 3, 4, 5]

# %%
del l3[2:5]

# %%
l3
# Out:
# [1, 2, 3, 4, 5]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
counter = [1, 2, 3, 4, 5, 6, 4, 5, 6]

# %%
counter.count(4)
# Out:
# 2

# %%
counter.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 counter.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
countercopy = counter.copy()

# %%
countercopy
# Out:
# [1, 2, 3, 4, 5, 6, 4, 5, 6]

# %%
counter.clear()

# %%
counter
# Out:
# []

# %%
countercopy
# Out:
# [1, 2, 3, 4, 5, 6, 4, 5, 6]

# %%
countercopy.reverse()

# %%
countercopy
# Out:
# [6, 5, 4, 6, 5, 4, 3, 2, 1]

# %%
sortedList = ['Apple', 'bat','Car', 'dog']
sortedList
# Out:
# ['Apple', 'bat', 'Car', 'dog']

# %%
sortedList.sort()
sortedList
# Out:
# ['Apple', 'Car', 'bat', 'dog']

# %%
sortedList = ['Apple', 'bat','Car', 'dog']

# %%
sortedList
# Out:
# ['Apple', 'bat', 'Car', 'dog']

# %%
sortedList.sort(key=str.lower)
sortedList
# Out:
# ['Apple', 'bat', 'Car', 'dog']
